# %% [markdown]
# <center><h1> Create dummy data </h1></center>

# %% [markdown]
# ## Which data do we need?
#     1. Table events:
#     event_id | event_name | event_address | event_start_date | event_end_date | event_start_time | event_end_time
#
#     2. Table users:
#     user_prename | user_name | user_email | user_alias | user_password | ticket_id | user_id | event_id
#
#     3. Table pickups:
#     pickup_cities | pickup_zip_code
#
#     4. Table journey:
#     event_address | pickup_zip_code | user_id | journey_id | journey_empty_spaces | journey_car | event_id | journey_text | journey_date | event_date | journey_start_time | event_start_time
#
#     5. Table reservation:
#     journey_id | reservation_requested_seats | journey_empty_spaces | reservation_text | user_id | journey_user_id

# %%
# --------------- creds --------------- 
import uuid # random unique IDs
import pandas as pd # Dataframes
from faker import Faker # create random data
from random import randint # random numbers for creation of test data
import sys
DATA_PATH = sys.path[0].replace("notebooks", "base_data")

# %%
# --------------- table events ---------------
table_events = pd.DataFrame({
    "event_id" : ["2ab60824-b539-4a1f-ae1a-f7d94d2d55bb",
                 "7be626b0-c1cd-4a26-a111-60afb13ba940"],
    "event_name" : ["Eintracht Frankfurt vs. FC Bayern München",
                   "World Club Dome"],
    "event_address" : ["Mörfelder Landstraße 362, 60528 Frankfurt am Main",
                      "Mörfelder Landstraße 362, 60528 Frankfurt am Main"],
    "event_start_date" : ["2020-06-01",
                         "2020-06-05"],
    "event_end_date" : ["2020-06-01",
                       "2020-06-07"],
    "event_start_time" : ["15:30:00",
                         "20:00:00"],
    "event_end_time" : ["18:00:00",
                       "18:00:00"]
})
table_events.to_csv(DATA_PATH + "\\table_events.csv", index=False)
table_events
# Out:
#                                event_id  \
# 0  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb
# 1  7be626b0-c1cd-4a26-a111-60afb13ba940
#
#                                   event_name  \
# 0  Eintracht Frankfurt vs. FC Bayern München
# 1                            World Club Dome
#
#                                        event_address event_start_date  \
# 0  Mörfelder Landstraße 362, 60528 Frankfurt am Main       2020-06-01
# 1  Mörfelder Landstraße 362, 60528 Frankfurt am Main       2020-06-05
#
#   event_end_date event_start_time event_end_time
# 0     2020-06-01         15:30:00       18:00:00
# 1     2020-06-07         20:00:00       18:00:00

# %%
# --------------- table users ---------------
table_user = []
faker = Faker(["de_DE"])

for i in range(1, 101):
    table_user.append({
        "user_id": uuid.uuid4(),
        "user_email" : faker.email(),
        "username" : faker.user_name(),
        "user_password" : faker.password()
        })
    
table_user = pd.DataFrame(table_user)
table_user = table_user[["user_id", "username", "user_email", "user_password"]]
table_user.loc[len(table_user)] = [str(uuid.uuid4())] + ["yannik"] + ["eventwaytest1234@googlemail.com"] + ["funktioniert noch nicht"]
table_user.to_csv(DATA_PATH + "\\table_user.csv", index=False)
table_user
# Out:
#                                   user_id         username  \
# 0    107708be-1d4d-4bdf-8e03-0dca12d4198d      wulfmattias
# 1    450c6b6e-0ec6-49e5-bb4b-1fc64bc2ab27       angelica79
# 2    8a27f87b-738c-4564-b01d-5d91ef2af558       dagobert98
# 3    81bd48d9-a690-45a6-b250-2d829f03fc09         vlangern
# 4    e4355698-ac7c-424d-a8e7-b650335bcced          sibel38
# ..                                    ...              ...
# 96   c5e623bb-4f8e-4a66-be8b-51a6b6098430  sigismundscheel
# 97   4bc5a02d-7be8-46ce-a9eb-9932f432d4e3       adelbert13
# 98   d7112750-9588-4de5-b872-18c5528171bc        nhenschel
# 99   b1e713e9-d6ae-4e31-93f9-4fd905ec5312      frankeachim
# 100  b674b80a-ba98-4b0d-ba95-c87b2c3aace4           yannik
#
#                           user_email            user_password
# 0              zirmezeynep@keudel.de               D_7GJzHlF#
# 1             luigiwagner@keudel.com               $vS3mCZaUI
# 2                 ekabus@seifert.org               *khPyGyNI6
# 3          haraldheuser@pruschke.com               M)H65ETyXO
# 4                 qluebs@margraf.org               I%4BWOrp$u
# ..                               ...                      ...
# 96        annekatringutknecht@web.de               _IwRfr4Tw6
# 97           tackermann@lachmann.com               &*Vg%$@Ey7
# 98           tmeister@googlemail.com               7vT59W_l2@
# 99         mariettabender@walter.org               8q7Bzf6ko)
# 100  eventwaytest1234@googlemail.com  funktioniert noch nicht
#
# [101 rows x 4 columns]

# %%
# --------------- table_pickups ---------------
table_pickups = pd.read_csv("D:/TechTalents/project-tt-app/server/base_data/German-Zip-Codes.csv", sep = ";")
table_pickups = table_pickups[["Ort", "Plz"]]
table_pickups = table_pickups.rename(columns={"Ort" : "pickup_city", "Plz": "pickup_zip_code"})
table_pickups = table_pickups.dropna()
table_pickups["pickup_zip_code"] = table_pickups["pickup_zip_code"].astype(int)
table_pickups.to_csv(DATA_PATH + "\\table_pickups.csv", index=False)
table_pickups
# Out:
#          pickup_city  pickup_zip_code
# 0               Aach            54298
# 1               Aach            78267
# 2             Aachen            52062
# 3             Aachen            52064
# 4             Aachen            52066
# ...              ...              ...
# 19669    Zwingenberg            69439
# 19670  Zwischendeich            19322
# 19671        Zwochau             4509
# 19672        Zwönitz             8297
# 19673          Zwota             8267
#
# [19670 rows x 2 columns]

# %%
# --------------- table_journey ---------------
table_journey = []
car_manufactures = ["Abarth","Alfa Romeo","Aston Martin","Audi","Bentley","BMW","Bugatti","Cadillac","Chevrolet","Chrysler",
                    "Citroën","Dacia","Daewoo","Daihatsu","Dodge","Donkervoort","DS","Ferrari","Fiat","Fisker","Ford",
                    "Honda","Hummer","Hyundai","Infiniti","Iveco","Jaguar","Jeep","Kia","KTM","Lada","Lamborghini",
                    "Lancia","Land Rover","Landwind","Lexus","Lotus","Maserati","Maybach","Mazda","McLaren","Mercedes-Benz",
                    "MG","Mini","Mitsubishi","Morgan","Nissan","Opel","Peugeot","Porsche","Renault","Rolls-Royce","Rover",
                    "Saab","Seat","Skoda","Smart","SsangYong","Subaru","Suzuki","Tesla","Toyota","Volkswagen","Volvo"]
for i in range(1, 51):
    x = randint(0, len(table_events)-1)
    y = randint(0, len(table_pickups)-1)
    z = randint(0, len(table_user)-1)
    a = randint(0, len(car_manufactures)-1)
    table_journey.append({
        "event_address" : table_events["event_address"][x],
        "event_id" : table_events["event_id"][x],
        "event_start_date" : table_events["event_start_date"][x],
        "event_start_time" : table_events["event_start_time"][x],
        "pickup_zip_code" : table_pickups["pickup_city"][y],
        "user_id": table_user["user_id"][z],
        "journey_id": uuid.uuid4(),
        "journey_empty_spaces": randint(1, 5),
        "journey_car": car_manufactures[a],
        "journey_text": faker.text(),
        "journey_date": table_events["event_start_date"][x],
        "journey_start_time": faker.time()[0:5],
        "journey_money": randint(0, 30)
    })

table_journey = pd.DataFrame(table_journey)
table_journey.to_csv(DATA_PATH + "\\table_journey.csv", index=False)
table_journey
# Out:
#                                         event_address  \
# 0   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 1   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 2   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 3   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 4   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 5   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 6   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 7   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 8   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 9   Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 10  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 11  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 12  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 13  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 14  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 15  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 16  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 17  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 18  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 19  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 20  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 21  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 22  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 23  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 24  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 25  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 26  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 27  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 28  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 29  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 30  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 31  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 32  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 33  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 34  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 35  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 36  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 37  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 38  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 39  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 40  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 41  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 42  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 43  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 44  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 45  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 46  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 47  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 48  Mörfelder Landstraße 362, 60528 Frankfurt am Main
# 49  Mörfelder Landstraße 362, 60528 Frankfurt am Main
#
#                                 event_id event_start_date event_start_time  \
# 0   2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 1   2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 2   2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 3   7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 4   2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 5   2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 6   7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 7   7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 8   7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 9   7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 10  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 11  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 12  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 13  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 14  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 15  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 16  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 17  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 18  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 19  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 20  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 21  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 22  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 23  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 24  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 25  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 26  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 27  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 28  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 29  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 30  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 31  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 32  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 33  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 34  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 35  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 36  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 37  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 38  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 39  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 40  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 41  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 42  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 43  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 44  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 45  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 46  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 47  2ab60824-b539-4a1f-ae1a-f7d94d2d55bb       2020-06-01         15:30:00
# 48  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
# 49  7be626b0-c1cd-4a26-a111-60afb13ba940       2020-06-05         20:00:00
#
#             pickup_zip_code                               user_id  \
# 0                 Jerischke  0e606daa-c042-4679-80c5-a27cd3c1f51e
# 1                   Karwitz  1566dde3-5d0a-4360-9df8-f6f1601c06c7
# 2               Schönermark  e4355698-ac7c-424d-a8e7-b650335bcced
# 3   Münsterschwarzach Abtei  81bd48d9-a690-45a6-b250-2d829f03fc09
# 4               Hagermarsch  34aee3cb-11fa-4261-9ea3-f35f76ccdbb7
# 5               Weilmünster  9beb8a6c-6e3b-4cd0-a115-a766749ffd40
# 6                Kiekebusch  d14d9b82-ad9a-4686-be32-5422d253d56d
# 7                Langendorf  25dfec07-e0f2-48d5-acfb-fc06bf499225
# 8                 Budenbach  78c432ed-3e4b-452a-acc2-abc4d8da0fb3
# 9         Niedertaufkirchen  d7112750-9588-4de5-b872-18c5528171bc
# 10                  Hamburg  5dc6247d-754b-4032-b152-a9992b54f78b
# 11                 Duisburg  16a62d72-6de3-42c3-87b0-62d2cf2b812a
# 12               Grettstadt  faffdde7-8a91-4fe3-abc2-cd354f4b36b8
# 13                   Icking  b81590c4-e5a3-468a-b68c-caf25b63881d
# 32  Ipsam in saepe officiis explicabo sit sit. Ali...   2020-06-05
# 33  Optio est neque eaque natus nam.\nRerum aspern...   2020-06-05
# 34  Magnam officia natus nihil quae error. Quod ma...   2020-06-05
# 35  Voluptates soluta excepturi ratione. Debitis r...   2020-06-05
# 36  Amet vel aut commodi voluptatem. Officiis ad b...   2020-06-05
# 37  Repellendus rem explicabo culpa nisi sed ullam...   2020-06-01
# 38  Aperiam fuga aperiam itaque distinctio alias a...   2020-06-05
# 39  Aliquid officiis rem iusto molestias ab quam. ...   2020-06-05
# 40  Quo porro libero perspiciatis voluptatibus. Ne...   2020-06-05
# 41  Officia accusamus accusantium necessitatibus.\...   2020-06-01
# 42  Perferendis fuga molestiae.\nIllum vero est fu...   2020-06-01
# 43  Ex totam temporibus porro. Quis vero aspernatu...   2020-06-01
# 44  Occaecati pariatur iusto quos unde dignissimos...   2020-06-05
# 45  Rerum at error autem porro eveniet reprehender...   2020-06-05
# 46  Ea pariatur assumenda ducimus. Numquam volupta...   2020-06-05
# 47  Esse necessitatibus velit et occaecati exceptu...   2020-06-01
# 48  Necessitatibus aliquid ipsum molestias. Nobis ...   2020-06-05
# 49  Id totam facilis rerum esse. Ad officia quaera...   2020-06-05
#
#    journey_start_time  journey_money
# 0               23:49             11
# 1               02:47             22
# 2               14:40             30
# 3               04:22             13
# 4               18:44             22
# 5               21:53             10
# 6               14:07              5
# 7               07:49             30
# 8               15:13              3
# 9               20:01              1
# 10              21:43              2
# 11              03:34             26
# 12              12:39             12
# 13              22:34             21
# 14              14:31              2
# 15              21:54              0
# 16              10:55              4
# 17              06:49             26
# 18              12:56              7
# 19              05:58             30
# 20              16:47             29
# 21              21:56             12
# 22              02:21             14
# 23              00:52             20
# 24              20:26             17
# 25              17:00             21
# 26              10:25             26
# 27              20:49             10
# 28              05:38             12
# 29              09:20             22
# 30              03:47             22
# 31              05:23              8
# 32              21:52             22
# 33              19:19              6
# 34              00:41             27
# 35              11:01             20
# 36              13:29             25
# 37              07:54              9
# 38              02:01             30
# 39              21:00             24
# 40              17:12             20
# 41              07:14              6
# 42              10:44             16
# 43              12:00             21
# 44              20:22             14
# 45              08:27             30
# 46              22:07             19
# 47              09:45             11
# 48              03:23             13
# 49              11:02             27

# %%
# --------------- table reservation ---------------
table_reservation = []
for i in range(1, 31):
    x = randint(0, len(table_events)-1)
    table_reservation.append({
        "reservation_id": uuid.uuid4(),
        "journey_id" : table_journey["journey_id"][x],
        "reservation_requested_seats" : randint(1, 5),
        "journey_empty_spaces" : table_journey["journey_empty_spaces"][x],
        "reservation_text" : faker.text(),
        "user_id": table_user["user_id"][randint(0, len(table_user)-1)],
        "journey_user_id": table_journey["user_id"][x],
        "reservation_money": randint(0, 30),
        "reservation_status": "pending"
    })
table_reservation = pd.DataFrame(table_reservation)
table_reservation = table_reservation[["reservation_id", "journey_id", "reservation_requested_seats",
                                       "journey_empty_spaces", "reservation_text",
                                       "user_id", "journey_user_id", "reservation_money", "reservation_status"]]
table_reservation.to_csv(DATA_PATH + "\\table_reservation.csv", index=False)
table_reservation
# Out:
#                           reservation_id  \
# 0   d1dd2ade-b6c6-4b16-a580-1bced71c44c5
# 1   7b3a81aa-2be7-4122-99df-05e7ece44fed
# 2   a6c7a131-ac82-4843-9a27-f844d63fd8d5
# 3   82088162-30d3-40dd-ac16-bfe6aa9ffdfb
# 4   9bba3e83-78d5-47a4-8b7a-488a3b1911f3
# 5   0a073f41-5036-42e3-8a69-b6a0a54a473b
# 6   ee29d5d2-8bca-40e5-b392-a0e3368af2a2
# 7   1bcd69df-4343-43db-9824-c2963df46781
# 8   a1c2f9bf-95f4-4d3f-baff-5511ee56f88d
# 9   381668bc-c413-4fce-88dd-88a0002dd7b6
# 10  4f667523-22df-412f-a626-59c116109578
# 11  1e686357-5a3b-4364-9251-9f4f9601265f
# 12  0278de62-c597-4f22-a7f9-d8957e648706
# 13  6c3b6ce4-fc5d-4f33-a059-e2a3c08b6522
# 14  755dad70-1c7e-485c-afc6-e18633133e34
# 15  9a5387df-f1db-4f0c-a5e5-4b7ff6271fb3
# 16  c0a5d0a3-23e6-4467-a8d7-a8f04a64e151
# 17  885c5ab3-a105-4ca3-89ca-f2fc996c131d
# 18  f9197861-5f57-4362-a7c4-de60f1f994ad
# 19  09dcb7fc-92ff-4028-acd8-0c46f5310257
# 20  96584819-1997-4d93-9555-96c1c7299d53
# 21  1b03127a-87c6-41bc-afc4-3a7d46001231
# 22  7b931579-9103-40ec-bba5-9a5272a8dcc7
# 23  8ad49b72-631e-49bc-8073-7f7374df714e
# 24  8363dd2b-b015-4016-b90f-8491ebf8a5ad
# 25  a282cede-ccd3-4dbd-997b-05276b49c721
# 26  8f4cef48-843d-44b1-9ccb-e7ca81140112
# 27  e97c0051-49ad-41c4-b19b-fa966dd6ca78
# 28  79968794-a4b0-4a55-981d-43581c03cf23
# 29  e2433ddb-0cfc-461c-9d0d-55314effeb4d
#
#                               journey_id  reservation_requested_seats  \
# 0   4f255198-a7f6-4530-a976-ccefbd1f2250                            1
# 1   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            5
# 2   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            5
# 3   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            3
# 4   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            2
# 5   4f255198-a7f6-4530-a976-ccefbd1f2250                            2
# 6   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            2
# 7   4f255198-a7f6-4530-a976-ccefbd1f2250                            3
# 8   0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            3
# 9   4f255198-a7f6-4530-a976-ccefbd1f2250                            3
# 10  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            3
# 11  4f255198-a7f6-4530-a976-ccefbd1f2250                            5
# 12  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            4
# 13  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            4
# 14  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            4
# 15  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            5
# 16  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            3
# 17  4f255198-a7f6-4530-a976-ccefbd1f2250                            3
# 18  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            4
# 19  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            3
# 20  4f255198-a7f6-4530-a976-ccefbd1f2250                            5
# 21  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            2
# 22  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                            5
# 23  0ab7c6eb-e442-4e4a-8086-9d964ac3b2fc                
# 14  7aa33844-2e7c-49ed-a695-ee9db3218505
# 15  7aa33844-2e7c-49ed-a695-ee9db3218505
# 16  2be8af87-a122-4b6c-9d56-88822dd0f8de
# 17  0ae425b4-1e4b-4cc8-b692-8ec17a4a6536
# 18  a12259ff-3ca1-4e19-8fde-3e839865dade
# 19  177a80d5-7e94-4025-80ba-fd99d5a71f4c
# 20  5dc6247d-754b-4032-b152-a9992b54f78b
# 21  ac4aa56c-ba05-40b0-9294-a88cf1d1c681
# 22  c9a499d9-e628-4f68-b9cf-79924b99bd82
# 23  25dfec07-e0f2-48d5-acfb-fc06bf499225
# 24  65b493a5-5d60-4c3d-8f95-658003f5e126
# 25  b9dac99f-082d-447f-9a95-c5df693a6c02
# 26  fee7e0fe-f169-496f-a47e-99a640928c34
# 27  7431e67e-95eb-4d6d-818b-5e6c3b9d3e4a
# 28  0118f914-0c7b-46c9-aa60-86e9d40f8370
# 29  c5afbefb-15c4-44e9-b42c-11e8c6392c8c
#
#                          journey_user_id  reservation_money reservation_status
# 0   1566dde3-5d0a-4360-9df8-f6f1601c06c7                 20            pending
# 1   0e606daa-c042-4679-80c5-a27cd3c1f51e                  7            pending
# 2   0e606daa-c042-4679-80c5-a27cd3c1f51e                  0            pending
# 3   0e606daa-c042-4679-80c5-a27cd3c1f51e                 10            pending
# 4   0e606daa-c042-4679-80c5-a27cd3c1f51e                 26            pending
# 5   1566dde3-5d0a-4360-9df8-f6f1601c06c7                 11            pending
# 6   0e606daa-c042-4679-80c5-a27cd3c1f51e                 13            pending
# 7   1566dde3-5d0a-4360-9df8-f6f1601c06c7                  5            pending
# 8   0e606daa-c042-4679-80c5-a27cd3c1f51e                 22            pending
# 9   1566dde3-5d0a-4360-9df8-f6f1601c06c7                 21            pending
# 10  0e606daa-c042-4679-80c5-a27cd3c1f51e                 20            pending
# 11  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 24            pending
# 12  0e606daa-c042-4679-80c5-a27cd3c1f51e                 15            pending
# 13  0e606daa-c042-4679-80c5-a27cd3c1f51e                 29            pending
# 14  0e606daa-c042-4679-80c5-a27cd3c1f51e                 15            pending
# 15  0e606daa-c042-4679-80c5-a27cd3c1f51e                 22            pending
# 16  0e606daa-c042-4679-80c5-a27cd3c1f51e                 12            pending
# 17  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 20            pending
# 18  0e606daa-c042-4679-80c5-a27cd3c1f51e                  4            pending
# 19  0e606daa-c042-4679-80c5-a27cd3c1f51e                 27            pending
# 20  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 12            pending
# 21  0e606daa-c042-4679-80c5-a27cd3c1f51e                 20            pending
# 22  0e606daa-c042-4679-80c5-a27cd3c1f51e                 15            pending
# 23  0e606daa-c042-4679-80c5-a27cd3c1f51e                 30            pending
# 24  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 26            pending
# 25  1566dde3-5d0a-4360-9df8-f6f1601c06c7                  9            pending
# 26  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 22            pending
# 27  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 26            pending
# 28  1566dde3-5d0a-4360-9df8-f6f1601c06c7                 12            pending
# 29  0e606daa-c042-4679-80c5-a27cd3c1f51e                 10            pending
